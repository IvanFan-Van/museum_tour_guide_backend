# %%
# %pip show ipykernel
# Out:
# Running cells with 'Python' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.

# %%
from pathlib import Path
from dotenv import load_dotenv, find_dotenv
import sys
import os

load_dotenv(find_dotenv())

sys.path.append("..")
os.chdir("..")
os.getcwd()
# Out:
# Running cells with 'server (Python 3.12.11)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"d:/HKU/Inno Wing RA/UBC Exchange/museum_tour_guide/backend/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
from src.retrieval_graph import retrieval_graph

messages = [{"role": "user", "content": "tell me something about kangxi"}]
results = await retrieval_graph.ainvoke({"messages": messages})
results
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.retrieval_graph import retrieval_graph
#       3 messages = [{"role": "user", "content": "tell me something about kangxi"}]
#       4 results = await retrieval_graph.ainvoke({"messages": messages})
#
# File d:\HKU\Inno Wing RA\UBC Exchange\museum_tour_guide\backend\src\retrieval_graph.py:4
#       1 """定义检索图子图 - 包含检索和重排序节点"""
#       3 import asyncio
# ----> 4 from langgraph.graph import START, StateGraph, END
#       5 from langchain_core.documents import Document
#       6 from chromadb import PersistentClient
#
# ModuleNotFoundError: No module named 'langgraph'

# %%
results["docs"][0].id

# %%
from chromadb import PersistentClient

client = PersistentClient(path="./chroma_db")

# %%
from pathlib import Path
import hashlib

data_folder = Path("./data/Objectifying_China/docs")


def get_file_id(file_path: str) -> str:
    return hashlib.md5(open(file_path, "rb").read()).hexdigest()


batch = {"ids": [], "documents": [], "metadatas": []}
for filepath in data_folder.glob("*.md"):
    with open(filepath, "r", encoding="utf-8") as f:
        text = f.read()
        print(get_file_id(str(filepath)), filepath.name)
        batch["ids"].append(get_file_id(str(filepath)))
        batch["documents"].append(text)
        batch["metadatas"].append({"source": filepath.name})

# %%
collection = client.get_or_create_collection(name="museum_knowledge_base")

# %%
collection.add(**batch)
